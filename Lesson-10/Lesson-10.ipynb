# %% [markdown]
# ### Задание
#
# Разобраться с моделькой перевода как она устроена
# запустить для перевода с русского на английский (при желании можно взять другие пары языков) два варианта с вниманием и без внимания
# оценить качество насколько корректно переводит (для теста отобрать примеры с увеличением длины текста) (так как оценка визуальная достаточно 20-ти примеров в тестовой выборке)

# %%
import re
import io
import os
import tensorflow as tf
import time
import numpy as np

from sklearn.model_selection import train_test_split

# %%
path = "./rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
    w = w.lower().strip()

    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

    w = w.strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

    word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

    return zip(*word_pairs)

# %%
en, ru = create_dataset(path, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
        filters='')
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

    return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
    # creating cleaned input, output pairs
    targ_lang, inp_lang = create_dataset(path, num_examples)

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
    for t in tensor:
        if t!=0:
            print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 14 ----> у
# 16 ----> меня
# 293 ----> руки
# 922 ----> устали
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 21 ----> my
# 1352 ----> arms
# 20 ----> are
# 164 ----> tired
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

    def call(self, x, hidden):
        # enc_output shape == (batch_size, max_length, hidden_size)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x, initial_state=hidden)

        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab)
        # fc - fully connected слой
        x = self.fc(output)

        return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# Убираем паддиноговые нулевые токены чтоб не учитывались в лоссе
# когда получаем падинговые элементы (0), то зануляем лосс
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    # inp - входная последовательность (русский)
    # target - английский
    # enc_hidden - вектор скрытого состояния энкодера
    loss = 0
    
    with tf.GradientTape() as tape
        enc_hidden = encoder(inp, enc_hidden)
        
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden = decoder(dec_input, dec_hidden)
            
            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

        batch_loss = (loss / int(targ.shape[1]))
        
        variables = encoder.trainable_variables + decoder.trainable_variables
        
        gradients = tape.gradient(loss, variables)

        optimizer.apply_gradients(zip(gradients, variables))
        
    return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.5393
# Epoch 1 Batch 100 Loss 1.9611
# Epoch 1 Batch 200 Loss 1.6905
# Epoch 1 Batch 300 Loss 1.6273
# Epoch 1 Batch 400 Loss 1.4904
# Epoch 1 Batch 500 Loss 1.4276
# Epoch 1 Batch 600 Loss 1.4086
# Epoch 1 Batch 700 Loss 1.2387
# Epoch 1 Batch 800 Loss 1.3205
# Epoch 1 Batch 900 Loss 1.2519
# Epoch 1 Batch 1000 Loss 1.1038
# Epoch 1 Batch 1100 Loss 1.0596
# Epoch 1 Batch 1200 Loss 1.1102
# Epoch 1 Loss 1.4360
# Time taken for 1 epoch 3925.748117685318 sec
#
# Epoch 2 Batch 0 Loss 0.8758
# Epoch 2 Batch 100 Loss 0.9703
# Epoch 2 Batch 200 Loss 0.8944
# Epoch 2 Batch 300 Loss 0.8035
# Epoch 2 Batch 400 Loss 0.8996
# Epoch 2 Batch 500 Loss 0.8842
# Epoch 2 Batch 600 Loss 0.7046
# Epoch 2 Batch 700 Loss 0.6875
# Epoch 2 Batch 800 Loss 0.7051
# Epoch 2 Batch 900 Loss 0.6485
# Epoch 2 Batch 1000 Loss 0.6875
# Epoch 2 Batch 1100 Loss 0.5901
# Epoch 2 Batch 1200 Loss 0.6047
# Epoch 2 Loss 0.7653
# Time taken for 1 epoch 3745.6542394161224 sec
#
# Epoch 3 Batch 0 Loss 0.4707
# Epoch 3 Batch 100 Loss 0.4136
# Epoch 3 Batch 200 Loss 0.5114
# Epoch 3 Batch 300 Loss 0.4225
# Epoch 3 Batch 400 Loss 0.4688
# Epoch 3 Batch 500 Loss 0.3936
# Epoch 3 Batch 600 Loss 0.3928
# Epoch 3 Batch 700 Loss 0.4283
# Epoch 3 Batch 800 Loss 0.4017
# Epoch 3 Batch 900 Loss 0.4367
# Epoch 3 Batch 1000 Loss 0.5153
# Epoch 3 Batch 1100 Loss 0.4242
# Epoch 3 Batch 1200 Loss 0.4602
# Epoch 3 Loss 0.4358
# Time taken for 1 epoch 3734.276553630829 sec
#
# Epoch 4 Batch 0 Loss 0.3055
# Epoch 4 Batch 100 Loss 0.2066
# Epoch 4 Batch 200 Loss 0.2217
# Epoch 4 Batch 300 Loss 0.2195
# Epoch 4 Batch 400 Loss 0.2534
# Epoch 4 Batch 500 Loss 0.2765
# Epoch 4 Batch 600 Loss 0.2428
# Epoch 4 Batch 700 Loss 0.3068
# Epoch 4 Batch 800 Loss 0.2383
# Epoch 4 Batch 900 Loss 0.2696
# Epoch 4 Batch 1000 Loss 0.2980
# Epoch 4 Batch 1100 Loss 0.2959
# Epoch 4 Batch 1200 Loss 0.2572
# Epoch 4 Loss 0.2608
# Time taken for 1 epoch 3757.5113937854767 sec
#
# Epoch 5 Batch 0 Loss 0.1577
# Epoch 5 Batch 100 Loss 0.1631
# Epoch 5 Batch 200 Loss 0.1483
# Epoch 5 Batch 300 Loss 0.1787
# Epoch 5 Batch 400 Loss 0.1622
# Epoch 5 Batch 500 Loss 0.1884
# Epoch 5 Batch 600 Loss 0.1687
# Epoch 5 Batch 700 Loss 0.1574
# Epoch 5 Batch 800 Loss 0.1606
# Epoch 5 Batch 900 Loss 0.1892
# Epoch 5 Batch 1000 Loss 0.1632
# Epoch 5 Batch 1100 Loss 0.1859
# Epoch 5 Batch 1200 Loss 0.1760
# Epoch 5 Loss 0.1740
# Time taken for 1 epoch 2926.598056793213 sec
#
# Epoch 6 Batch 0 Loss 0.1146
# Epoch 6 Batch 100 Loss 0.0882
# Epoch 6 Batch 200 Loss 0.0922
# Epoch 6 Batch 300 Loss 0.1282
# Epoch 6 Batch 400 Loss 0.0830
# Epoch 6 Batch 500 Loss 0.1123
# Epoch 6 Batch 600 Loss 0.0896
# Epoch 6 Batch 700 Loss 0.1660
# Epoch 6 Batch 800 Loss 0.1253
# Epoch 6 Batch 900 Loss 0.1957
# Epoch 6 Batch 1000 Loss 0.1740
# Epoch 6 Batch 1100 Loss 0.1495
# Epoch 6 Batch 1200 Loss 0.1326
# Epoch 6 Loss 0.1298
# Time taken for 1 epoch 1872.2146649360657 sec
#
# Epoch 7 Batch 0 Loss 0.0701
# Epoch 7 Batch 100 Loss 0.0770
# Epoch 7 Batch 200 Loss 0.0606
# Epoch 7 Batch 300 Loss 0.0790
# Epoch 7 Batch 400 Loss 0.0632
# Epoch 7 Batch 500 Loss 0.0895
# Epoch 7 Batch 600 Loss 0.1020
# Epoch 7 Batch 700 Loss 0.0903
# Epoch 7 Batch 800 Loss 0.0689
# Epoch 7 Batch 900 Loss 0.1164
# Epoch 7 Batch 1000 Loss 0.1148
# Epoch 7 Batch 1100 Loss 0.1327
# Epoch 7 Batch 1200 Loss 0.1088
# Epoch 7 Loss 0.1080
# Time taken for 1 epoch 1849.4191029071808 sec
#
# Epoch 8 Batch 0 Loss 0.0697
# Epoch 8 Batch 100 Loss 0.0790
# Epoch 8 Batch 200 Loss 0.0833
# Epoch 8 Batch 300 Loss 0.0834
# Epoch 8 Batch 400 Loss 0.1107
# Epoch 8 Batch 500 Loss 0.0606
# Epoch 8 Batch 600 Loss 0.0630
# Epoch 8 Batch 700 Loss 0.1019
# Epoch 8 Batch 800 Loss 0.0852
# Epoch 8 Batch 900 Loss 0.0963
# Epoch 8 Batch 1000 Loss 0.1064
# Epoch 8 Batch 1100 Loss 0.0879
# Epoch 8 Batch 1200 Loss 0.0570
# Epoch 8 Loss 0.0959
# Time taken for 1 epoch 1853.3749563694 sec
#
# Epoch 9 Batch 0 Loss 0.0633
# Epoch 9 Batch 100 Loss 0.0477
# Epoch 9 Batch 200 Loss 0.0678
# Epoch 9 Batch 300 Loss 0.0785
# Epoch 9 Batch 400 Loss 0.0831
# Epoch 9 Batch 500 Loss 0.1086
# Epoch 9 Batch 600 Loss 0.0974
# Epoch 9 Batch 700 Loss 0.0867
# Epoch 9 Batch 800 Loss 0.0741
# Epoch 9 Batch 900 Loss 0.0852
# Epoch 9 Batch 1000 Loss 0.0879
# Epoch 9 Batch 1100 Loss 0.0994
# Epoch 9 Batch 1200 Loss 0.1103
# Epoch 9 Loss 0.0879
# Time taken for 1 epoch 1856.1007647514343 sec
#
# Epoch 10 Batch 0 Loss 0.0737
# Epoch 10 Batch 100 Loss 0.0687
# Epoch 10 Batch 200 Loss 0.0527
# Epoch 10 Batch 300 Loss 0.0650
# Epoch 10 Batch 400 Loss 0.0735
# Epoch 10 Batch 500 Loss 0.0708
# Epoch 10 Batch 600 Loss 0.0753
# Epoch 10 Batch 700 Loss 0.0959
# Epoch 10 Batch 800 Loss 0.0614
# Epoch 10 Batch 900 Loss 0.1028
# Epoch 10 Batch 1000 Loss 0.1316
# Epoch 10 Batch 1100 Loss 0.1088
# Epoch 10 Batch 1200 Loss 0.0907
# Epoch 10 Loss 0.0822
# Time taken for 1 epoch 1861.7523064613342 sec
#
# Epoch 11 Batch 0 Loss 0.0587
# Epoch 11 Batch 100 Loss 0.0903
# Epoch 11 Batch 200 Loss 0.0755
# Epoch 11 Batch 300 Loss 0.0576
# Epoch 11 Batch 400 Loss 0.0684
# Epoch 11 Batch 500 Loss 0.1042
# Epoch 11 Batch 600 Loss 0.0341
# Epoch 11 Batch 700 Loss 0.0691
# Epoch 11 Batch 800 Loss 0.0842
# Epoch 11 Batch 900 Loss 0.0897
# Epoch 11 Batch 1000 Loss 0.0715
# Epoch 11 Batch 1100 Loss 0.0942
# Epoch 11 Batch 1200 Loss 0.0908
# Epoch 11 Loss 0.0789
# Time taken for 1 epoch 1860.7781796455383 sec
#
# Epoch 12 Batch 0 Loss 0.0653
# Epoch 12 Batch 100 Loss 0.0704
# Epoch 12 Batch 200 Loss 0.0767
# Epoch 12 Batch 300 Loss 0.0963
# Epoch 12 Batch 400 Loss 0.0784
# Epoch 12 Batch 500 Loss 0.0823
# Epoch 12 Batch 600 Loss 0.0808
# Epoch 12 Batch 700 Loss 0.0967
# Epoch 12 Batch 800 Loss 0.0789
# Epoch 12 Batch 900 Loss 0.0710
# Epoch 12 Batch 1000 Loss 0.0999
# Epoch 12 Batch 1100 Loss 0.0905
# Epoch 12 Batch 1200 Loss 0.0743
# Epoch 12 Loss 0.0765
# Time taken for 1 epoch 1869.414558649063 sec
#
# Epoch 13 Batch 0 Loss 0.0656
# Epoch 13 Batch 100 Loss 0.0567
# Epoch 13 Batch 200 Loss 0.0675
# Epoch 13 Batch 300 Loss 0.0811
# Epoch 13 Batch 400 Loss 0.0526
# Epoch 13 Batch 500 Loss 0.0488
# Epoch 13 Batch 600 Loss 0.0639
# Epoch 13 Batch 700 Loss 0.0764
# Epoch 13 Batch 800 Loss 0.1244
# Epoch 13 Batch 900 Loss 0.0854
# Epoch 13 Batch 1000 Loss 0.1005
# Epoch 13 Batch 1100 Loss 0.0948
# Epoch 13 Batch 1200 Loss 0.0858
# Epoch 13 Loss 0.0733
# Time taken for 1 epoch 1874.9993617534637 sec
#
# Epoch 14 Batch 0 Loss 0.0500
# Epoch 14 Batch 100 Loss 0.0444
# Epoch 14 Batch 200 Loss 0.0491
# Epoch 14 Batch 300 Loss 0.0791
# Epoch 14 Batch 400 Loss 0.0615
# Epoch 14 Batch 500 Loss 0.0382
# Epoch 14 Batch 600 Loss 0.0679
# Epoch 14 Batch 700 Loss 0.0894
# Epoch 14 Batch 800 Loss 0.0554
# Epoch 14 Batch 900 Loss 0.0770
# Epoch 14 Batch 1000 Loss 0.0751
# Epoch 14 Batch 1100 Loss 0.0984
# Epoch 14 Batch 1200 Loss 0.0704
# Epoch 14 Loss 0.0710
# Time taken for 1 epoch 1870.5703835487366 sec
#
# Epoch 15 Batch 0 Loss 0.0626
# Epoch 15 Batch 100 Loss 0.0276
# Epoch 15 Batch 200 Loss 0.0538
# Epoch 15 Batch 300 Loss 0.0654
# Epoch 15 Batch 400 Loss 0.0600
# Epoch 15 Batch 500 Loss 0.0675
# Epoch 15 Batch 600 Loss 0.0544
# Epoch 15 Batch 700 Loss 0.0670
# Epoch 15 Batch 800 Loss 0.1125
# Epoch 15 Batch 900 Loss 0.0464
# Epoch 15 Batch 1000 Loss 0.0644
# Epoch 15 Batch 1100 Loss 0.0542
# Epoch 15 Batch 1200 Loss 0.0836
# Epoch 15 Loss 0.0693
# Time taken for 1 epoch 1877.6760187149048 sec
#
# Epoch 16 Batch 0 Loss 0.0543
# Epoch 16 Batch 100 Loss 0.0695
# Epoch 16 Batch 200 Loss 0.0716
# Epoch 16 Batch 300 Loss 0.0731
# Epoch 16 Batch 400 Loss 0.0789
# Epoch 16 Batch 500 Loss 0.0605
# Epoch 16 Batch 600 Loss 0.0931
# Epoch 16 Batch 700 Loss 0.0843
# Epoch 16 Batch 800 Loss 0.0658
# Epoch 16 Batch 900 Loss 0.0418
# Epoch 16 Batch 1000 Loss 0.0282
# Epoch 16 Batch 1100 Loss 0.0758
# Epoch 16 Batch 1200 Loss 0.0962
# Epoch 16 Loss 0.0676
# Time taken for 1 epoch 1956.2965123653412 sec
#
# Epoch 17 Batch 0 Loss 0.0247
# Epoch 17 Batch 100 Loss 0.0602
# Epoch 17 Batch 200 Loss 0.0314
# Epoch 17 Batch 300 Loss 0.0714
# Epoch 17 Batch 400 Loss 0.0402
# Epoch 17 Batch 500 Loss 0.0895
# Epoch 17 Batch 600 Loss 0.0769
# Epoch 17 Batch 700 Loss 0.0425
# Epoch 17 Batch 800 Loss 0.0722
# Epoch 17 Batch 900 Loss 0.1020
# Epoch 17 Batch 1000 Loss 0.0843
# Epoch 17 Batch 1100 Loss 0.0504
# Epoch 17 Batch 1200 Loss 0.0860
# Epoch 17 Loss 0.0662
# Time taken for 1 epoch 1948.9139330387115 sec
#
# Epoch 18 Batch 0 Loss 0.0458
# Epoch 18 Batch 100 Loss 0.0601
# Epoch 18 Batch 200 Loss 0.0956
# Epoch 18 Batch 300 Loss 0.0711
# Epoch 18 Batch 400 Loss 0.0466
# Epoch 18 Batch 500 Loss 0.0808
# Epoch 18 Batch 600 Loss 0.0348
# Epoch 18 Batch 700 Loss 0.0865
# Epoch 18 Batch 800 Loss 0.0944
# Epoch 18 Batch 900 Loss 0.0514
# Epoch 18 Batch 1000 Loss 0.0147
# Epoch 18 Batch 1100 Loss 0.0485
# Epoch 18 Batch 1200 Loss 0.0568
# Epoch 18 Loss 0.0648
# Time taken for 1 epoch 1942.0145058631897 sec
#
# Epoch 19 Batch 0 Loss 0.0699
# Epoch 19 Batch 100 Loss 0.0335
# Epoch 19 Batch 200 Loss 0.0350
# Epoch 19 Batch 300 Loss 0.0432
# Epoch 19 Batch 400 Loss 0.0759
# Epoch 19 Batch 500 Loss 0.0628
# Epoch 19 Batch 600 Loss 0.0555
# Epoch 19 Batch 700 Loss 0.0868
# Epoch 19 Batch 800 Loss 0.0695
# Epoch 19 Batch 900 Loss 0.0635
# Epoch 19 Batch 1000 Loss 0.0546
# Epoch 19 Batch 1100 Loss 0.0543
# Epoch 19 Batch 1200 Loss 0.0691
# Epoch 19 Loss 0.0636
# Time taken for 1 epoch 1956.5356936454773 sec
#
# Epoch 20 Batch 0 Loss 0.0724
# Epoch 20 Batch 100 Loss 0.0570
# Epoch 20 Batch 200 Loss 0.0632
# Epoch 20 Batch 300 Loss 0.0906
# Epoch 20 Batch 400 Loss 0.0544
# Epoch 20 Batch 500 Loss 0.0490
# Epoch 20 Batch 600 Loss 0.0482
# Epoch 20 Batch 700 Loss 0.0541
# Epoch 20 Batch 800 Loss 0.0863
# Epoch 20 Batch 900 Loss 0.0532
# Epoch 20 Batch 1000 Loss 0.0646
# Epoch 20 Batch 1100 Loss 0.0483
# Epoch 20 Batch 1200 Loss 0.0436
# Epoch 20 Loss 0.0628
# Time taken for 1 epoch 1933.3378891944885 sec
#
# Epoch 21 Batch 0 Loss 0.0364
# Epoch 21 Batch 100 Loss 0.0410
# Epoch 21 Batch 200 Loss 0.0597
# Epoch 21 Batch 300 Loss 0.0603
# Epoch 21 Batch 400 Loss 0.0749
# Epoch 21 Batch 500 Loss 0.0424
# Epoch 21 Batch 600 Loss 0.0785
# Epoch 21 Batch 700 Loss 0.0560
# Epoch 21 Batch 800 Loss 0.0812
# Epoch 21 Batch 900 Loss 0.0923
# Epoch 21 Batch 1000 Loss 0.0601
# Epoch 21 Batch 1100 Loss 0.0927
# Epoch 21 Batch 1200 Loss 0.0642
# Epoch 21 Loss 0.0616
# Time taken for 1 epoch 1945.941106557846 sec
#
# Epoch 22 Batch 0 Loss 0.0428
# Epoch 22 Batch 100 Loss 0.0580
# Epoch 22 Batch 200 Loss 0.0594
# Epoch 22 Batch 300 Loss 0.0252
# Epoch 22 Batch 400 Loss 0.1170
# Epoch 22 Batch 500 Loss 0.0603
# Epoch 22 Batch 600 Loss 0.0483
# Epoch 22 Batch 700 Loss 0.0545
# Epoch 22 Batch 800 Loss 0.0977
# Epoch 22 Batch 900 Loss 0.0855
# Epoch 22 Batch 1000 Loss 0.0510
# Epoch 22 Batch 1100 Loss 0.0769
# Epoch 22 Batch 1200 Loss 0.0886
# Epoch 22 Loss 0.0605
# Time taken for 1 epoch 1953.490555524826 sec
#
# Epoch 23 Batch 0 Loss 0.0229
# Epoch 23 Batch 100 Loss 0.0600
# Epoch 23 Batch 200 Loss 0.0274
# Epoch 23 Batch 300 Loss 0.0560
# Epoch 23 Batch 400 Loss 0.0259
# Epoch 23 Batch 500 Loss 0.0447
# Epoch 23 Batch 600 Loss 0.0351
# Epoch 23 Batch 700 Loss 0.0769
# Epoch 23 Batch 800 Loss 0.0617
# Epoch 23 Batch 900 Loss 0.0377
# Epoch 23 Batch 1000 Loss 0.0605
# Epoch 23 Batch 1100 Loss 0.0766
# Epoch 23 Batch 1200 Loss 0.0767
# Epoch 23 Loss 0.0598
# Time taken for 1 epoch 1955.611322402954 sec
#
# Epoch 24 Batch 0 Loss 0.0523
# Epoch 24 Batch 100 Loss 0.0471
# Epoch 24 Batch 200 Loss 0.0488
# Epoch 24 Batch 300 Loss 0.0728
# Epoch 24 Batch 400 Loss 0.0891
# Epoch 24 Batch 500 Loss 0.0495
# Epoch 24 Batch 600 Loss 0.0696
# Epoch 24 Batch 700 Loss 0.0409
# Epoch 24 Batch 800 Loss 0.1086
# Epoch 24 Batch 900 Loss 0.0316
# Epoch 24 Batch 1000 Loss 0.0481
# Epoch 24 Batch 1100 Loss 0.0569
# Epoch 24 Batch 1200 Loss 0.0991
# Epoch 24 Loss 0.0586
# Time taken for 1 epoch 1950.6305902004242 sec
#
# Epoch 25 Batch 0 Loss 0.0341
# Epoch 25 Batch 100 Loss 0.0199
# Epoch 25 Batch 200 Loss 0.0340
# Epoch 25 Batch 300 Loss 0.0445
# Epoch 25 Batch 400 Loss 0.0408
# Epoch 25 Batch 500 Loss 0.0748
# Epoch 25 Batch 600 Loss 0.0779
# Epoch 25 Batch 700 Loss 0.0845
# Epoch 25 Batch 800 Loss 0.0331
# Epoch 25 Batch 900 Loss 0.0715
# Epoch 25 Batch 1000 Loss 0.0521
# Epoch 25 Batch 1100 Loss 0.0369
# Epoch 25 Batch 1200 Loss 0.0545
# Epoch 25 Loss 0.0573
# Time taken for 1 epoch 1940.6150116920471 sec
#
# Epoch 26 Batch 0 Loss 0.0671
# Epoch 26 Batch 100 Loss 0.0462
# Epoch 26 Batch 200 Loss 0.0337
# Epoch 26 Batch 300 Loss 0.0263
# Epoch 26 Batch 400 Loss 0.0462
# Epoch 26 Batch 500 Loss 0.0632
# Epoch 26 Batch 600 Loss 0.0622
# Epoch 26 Batch 700 Loss 0.0631
# Epoch 26 Batch 800 Loss 0.0861
# Epoch 26 Batch 900 Loss 0.0787
# Epoch 26 Batch 1000 Loss 0.0349
# Epoch 26 Batch 1100 Loss 0.0432
# Epoch 26 Batch 1200 Loss 0.0631
# Epoch 26 Loss 0.0571
# Time taken for 1 epoch 1933.989752292633 sec
#
# Epoch 27 Batch 0 Loss 0.0345
# Epoch 27 Batch 100 Loss 0.0256
# Epoch 27 Batch 200 Loss 0.0709
# Epoch 27 Batch 300 Loss 0.0751
# Epoch 27 Batch 400 Loss 0.0335
# Epoch 27 Batch 500 Loss 0.0883
# Epoch 27 Batch 600 Loss 0.0562
# Epoch 27 Batch 700 Loss 0.0695
# Epoch 27 Batch 800 Loss 0.0657
# Epoch 27 Batch 900 Loss 0.0728
# Epoch 27 Batch 1000 Loss 0.0757
# Epoch 27 Batch 1100 Loss 0.0695
# Epoch 27 Batch 1200 Loss 0.0804
# Epoch 27 Loss 0.0560
# Time taken for 1 epoch 1944.9504787921906 sec
#
# Epoch 28 Batch 0 Loss 0.0538
# Epoch 28 Batch 100 Loss 0.0264
# Epoch 28 Batch 200 Loss 0.0204
# Epoch 28 Batch 300 Loss 0.0358
# Epoch 28 Batch 400 Loss 0.0506
# Epoch 28 Batch 500 Loss 0.0488
# Epoch 28 Batch 600 Loss 0.0599
# Epoch 28 Batch 700 Loss 0.0325
# Epoch 28 Batch 800 Loss 0.0446
# Epoch 28 Batch 900 Loss 0.0609
# Epoch 28 Batch 1000 Loss 0.0622
# Epoch 28 Batch 1100 Loss 0.1060
# Epoch 28 Batch 1200 Loss 0.0392
# Epoch 28 Loss 0.0553
# Time taken for 1 epoch 1934.0413899421692 sec
#
# Epoch 29 Batch 0 Loss 0.0247
# Epoch 29 Batch 100 Loss 0.0323
# Epoch 29 Batch 200 Loss 0.0552
# Epoch 29 Batch 300 Loss 0.0725
# Epoch 29 Batch 400 Loss 0.0406
# Epoch 29 Batch 500 Loss 0.0544
# Epoch 29 Batch 600 Loss 0.0344
# Epoch 29 Batch 700 Loss 0.0328
# Epoch 29 Batch 800 Loss 0.0488
# Epoch 29 Batch 900 Loss 0.0833
# Epoch 29 Batch 1000 Loss 0.0626
# Epoch 29 Batch 1100 Loss 0.0666
# Epoch 29 Batch 1200 Loss 0.0494
# Epoch 29 Loss 0.0544
# Time taken for 1 epoch 1937.3332076072693 sec
#
# Epoch 30 Batch 0 Loss 0.0433
# Epoch 30 Batch 100 Loss 0.0486
# Epoch 30 Batch 200 Loss 0.0238
# Epoch 30 Batch 300 Loss 0.0683
# Epoch 30 Batch 400 Loss 0.0619
# Epoch 30 Batch 500 Loss 0.0609
# Epoch 30 Batch 600 Loss 0.0484
# Epoch 30 Batch 700 Loss 0.0598
# Epoch 30 Batch 800 Loss 0.0554
# Epoch 30 Batch 900 Loss 0.0778
# Epoch 30 Batch 1000 Loss 0.0625
# Epoch 30 Batch 1100 Loss 0.0795
# Epoch 30 Batch 1200 Loss 0.0497
# Epoch 30 Loss 0.0536
# Time taken for 1 epoch 1943.6857113838196 sec
#
# Epoch 31 Batch 0 Loss 0.0393
# Epoch 31 Batch 100 Loss 0.0234
# Epoch 31 Batch 200 Loss 0.0275
# Epoch 31 Batch 300 Loss 0.0352
# Epoch 31 Batch 400 Loss 0.0833
# Epoch 31 Batch 500 Loss 0.0551
# Epoch 31 Batch 600 Loss 0.0251
# Epoch 31 Batch 700 Loss 0.0706
# Epoch 31 Batch 800 Loss 0.0438
# Epoch 31 Batch 900 Loss 0.0665
# Epoch 31 Batch 1000 Loss 0.0426
# Epoch 31 Batch 1100 Loss 0.0750
# Epoch 31 Batch 1200 Loss 0.0600
# Epoch 31 Loss 0.0532
# Time taken for 1 epoch 1931.5127685070038 sec
#
# Epoch 32 Batch 0 Loss 0.0419
# Epoch 32 Batch 100 Loss 0.0311
# Epoch 32 Batch 200 Loss 0.0500
# Epoch 32 Batch 300 Loss 0.0817
# Epoch 32 Batch 400 Loss 0.0623
# Epoch 32 Batch 500 Loss 0.0605
# Epoch 32 Batch 600 Loss 0.0252
# Epoch 32 Batch 700 Loss 0.0440
# Epoch 32 Batch 800 Loss 0.0589
# Epoch 32 Batch 900 Loss 0.0617
# Epoch 32 Batch 1000 Loss 0.0703
# Epoch 32 Batch 1100 Loss 0.0691
# Epoch 32 Batch 1200 Loss 0.0446
# Epoch 32 Loss 0.0523
# Time taken for 1 epoch 1960.4889948368073 sec
#
# Epoch 33 Batch 0 Loss 0.0843
# Epoch 33 Batch 100 Loss 0.0355
# Epoch 33 Batch 200 Loss 0.0384
# Epoch 33 Batch 300 Loss 0.0630
# Epoch 33 Batch 400 Loss 0.0561
# Epoch 33 Batch 500 Loss 0.0415
# Epoch 33 Batch 600 Loss 0.0409
# Epoch 33 Batch 700 Loss 0.0632
# Epoch 33 Batch 800 Loss 0.0528
# Epoch 33 Batch 900 Loss 0.0332
# Epoch 33 Batch 1000 Loss 0.0828
# Epoch 33 Batch 1100 Loss 0.0887
# Epoch 33 Batch 1200 Loss 0.0606
# Epoch 33 Loss 0.0520
# Time taken for 1 epoch 1952.1937413215637 sec
#
# Epoch 34 Batch 0 Loss 0.0455
# Epoch 34 Batch 100 Loss 0.0433
# Epoch 34 Batch 200 Loss 0.0451
# Epoch 34 Batch 300 Loss 0.0442
# Epoch 34 Batch 400 Loss 0.0404
# Epoch 34 Batch 500 Loss 0.0716
# Epoch 34 Batch 600 Loss 0.0643
# Epoch 34 Batch 700 Loss 0.0685
# Epoch 34 Batch 800 Loss 0.0931
# Epoch 34 Batch 900 Loss 0.0300
# Epoch 34 Batch 1000 Loss 0.0471
# Epoch 34 Batch 1100 Loss 0.0635
# Epoch 34 Batch 1200 Loss 0.0843
# Epoch 34 Loss 0.0511
# Time taken for 1 epoch 1954.952252626419 sec
#
# Epoch 35 Batch 0 Loss 0.0240
# Epoch 35 Batch 100 Loss 0.0602
# Epoch 35 Batch 200 Loss 0.0323
# Epoch 35 Batch 300 Loss 0.0429
# Epoch 35 Batch 400 Loss 0.0548
# Epoch 35 Batch 500 Loss 0.0382
# Epoch 35 Batch 600 Loss 0.0343
# Epoch 35 Batch 700 Loss 0.0503
# Epoch 35 Batch 800 Loss 0.0409
# Epoch 35 Batch 900 Loss 0.0855
# Epoch 35 Batch 1000 Loss 0.0586
# Epoch 35 Batch 1100 Loss 0.0589
# Epoch 35 Batch 1200 Loss 0.1096
# Epoch 35 Loss 0.0507
# Time taken for 1 epoch 1950.7234869003296 sec
#
# Epoch 36 Batch 0 Loss 0.0371
# Epoch 36 Batch 100 Loss 0.0443
# Epoch 36 Batch 200 Loss 0.0416
# Epoch 36 Batch 300 Loss 0.0254
# Epoch 36 Batch 400 Loss 0.0475
# Epoch 36 Batch 500 Loss 0.0483
# Epoch 36 Batch 600 Loss 0.0487
# Epoch 36 Batch 700 Loss 0.0412
# Epoch 36 Batch 800 Loss 0.0668
# Epoch 36 Batch 900 Loss 0.0793
# Epoch 36 Batch 1000 Loss 0.0396
# Epoch 36 Batch 1100 Loss 0.0591
# Epoch 36 Batch 1200 Loss 0.0852
# Epoch 36 Loss 0.0499
# Time taken for 1 epoch 1951.8575489521027 sec
#
# Epoch 37 Batch 0 Loss 0.0384
# Epoch 37 Batch 100 Loss 0.0543
# Epoch 37 Batch 200 Loss 0.0400
# Epoch 37 Batch 300 Loss 0.0397
# Epoch 37 Batch 400 Loss 0.0348
# Epoch 37 Batch 500 Loss 0.0481
# Epoch 37 Batch 600 Loss 0.0268
# Epoch 37 Batch 700 Loss 0.0267
# Epoch 37 Batch 800 Loss 0.0945
# Epoch 37 Batch 900 Loss 0.0483
# Epoch 37 Batch 1000 Loss 0.0742
# Epoch 37 Batch 1100 Loss 0.0640
# Epoch 37 Batch 1200 Loss 0.0784
# Epoch 37 Loss 0.0492
# Time taken for 1 epoch 1957.3648438453674 sec
#
# Epoch 38 Batch 0 Loss 0.0521
# Epoch 38 Batch 100 Loss 0.0445
# Epoch 38 Batch 200 Loss 0.0305
# Epoch 38 Batch 300 Loss 0.0414
# Epoch 38 Batch 400 Loss 0.0689
# Epoch 38 Batch 500 Loss 0.0668
# Epoch 38 Batch 600 Loss 0.0751
# Epoch 38 Batch 700 Loss 0.0784
# Epoch 38 Batch 800 Loss 0.0335
# Epoch 38 Batch 900 Loss 0.0639
# Epoch 38 Batch 1000 Loss 0.0376
# Epoch 38 Batch 1100 Loss 0.0797
# Epoch 38 Batch 1200 Loss 0.0365
# Epoch 38 Loss 0.0492
# Time taken for 1 epoch 1967.4300186634064 sec
#
# Epoch 39 Batch 0 Loss 0.0285
# Epoch 39 Batch 100 Loss 0.0322
# Epoch 39 Batch 200 Loss 0.0472
# Epoch 39 Batch 300 Loss 0.0221
# Epoch 39 Batch 400 Loss 0.0244
# Epoch 39 Batch 500 Loss 0.0343
# Epoch 39 Batch 600 Loss 0.0351
# Epoch 39 Batch 700 Loss 0.0560
# Epoch 39 Batch 800 Loss 0.0656
# Epoch 39 Batch 900 Loss 0.0577
# Epoch 39 Batch 1000 Loss 0.0595
# Epoch 39 Batch 1100 Loss 0.0609
# Epoch 39 Batch 1200 Loss 0.0362
# Epoch 39 Loss 0.0488
# Time taken for 1 epoch 1962.054992198944 sec
#
# Epoch 40 Batch 0 Loss 0.0237
# Epoch 40 Batch 100 Loss 0.0395
# Epoch 40 Batch 200 Loss 0.0468
# Epoch 40 Batch 300 Loss 0.0449
# Epoch 40 Batch 400 Loss 0.0278
# Epoch 40 Batch 500 Loss 0.0388
# Epoch 40 Batch 600 Loss 0.0400
# Epoch 40 Batch 700 Loss 0.0467
# Epoch 40 Batch 800 Loss 0.0673
# Epoch 40 Batch 900 Loss 0.0626
# Epoch 40 Batch 1000 Loss 0.0556
# Epoch 40 Batch 1100 Loss 0.0305
# Epoch 40 Batch 1200 Loss 0.0370
# Epoch 40 Loss 0.0479
# Time taken for 1 epoch 1973.392505645752 sec
#
# Epoch 41 Batch 0 Loss 0.0312
# Epoch 41 Batch 100 Loss 0.0489
# Epoch 41 Batch 200 Loss 0.0230
# Epoch 41 Batch 300 Loss 0.0575
# Epoch 41 Batch 400 Loss 0.0410
# Epoch 41 Batch 500 Loss 0.0185
# Epoch 41 Batch 600 Loss 0.0454
# Epoch 41 Batch 700 Loss 0.0409
# Epoch 41 Batch 800 Loss 0.0263
# Epoch 41 Batch 900 Loss 0.0661
# Epoch 41 Batch 1000 Loss 0.0649
# Epoch 41 Batch 1100 Loss 0.0389
# Epoch 41 Batch 1200 Loss 0.0561
# Epoch 41 Loss 0.0475
# Time taken for 1 epoch 1913.1290216445923 sec
#
# Epoch 42 Batch 0 Loss 0.0478
# Epoch 42 Batch 100 Loss 0.0459
# Epoch 42 Batch 200 Loss 0.0304
# Epoch 42 Batch 300 Loss 0.0587
# Epoch 42 Batch 400 Loss 0.0508
# Epoch 42 Batch 500 Loss 0.0399
# Epoch 42 Batch 600 Loss 0.0356
# Epoch 42 Batch 700 Loss 0.0675
# Epoch 42 Batch 800 Loss 0.0531
# Epoch 42 Batch 900 Loss 0.0502
# Epoch 42 Batch 1000 Loss 0.0523
# Epoch 42 Batch 1100 Loss 0.0832
# Epoch 42 Batch 1200 Loss 0.0646
# Epoch 42 Loss 0.0474
# Time taken for 1 epoch 1923.6905043125153 sec
#
# Epoch 43 Batch 0 Loss 0.0243
# Epoch 43 Batch 100 Loss 0.0276
# Epoch 43 Batch 200 Loss 0.0419
# Epoch 43 Batch 300 Loss 0.0196
# Epoch 43 Batch 400 Loss 0.0609
# Epoch 43 Batch 500 Loss 0.0867
# Epoch 43 Batch 600 Loss 0.0484
# Epoch 43 Batch 700 Loss 0.0399
# Epoch 43 Batch 800 Loss 0.0504
# Epoch 43 Batch 900 Loss 0.0487
# Epoch 43 Batch 1000 Loss 0.0574
# Epoch 43 Batch 1100 Loss 0.0630
# Epoch 43 Batch 1200 Loss 0.0373
# Epoch 43 Loss 0.0467
# Time taken for 1 epoch 1958.4424617290497 sec
#
# Epoch 44 Batch 0 Loss 0.0105
# Epoch 44 Batch 100 Loss 0.0348
# Epoch 44 Batch 200 Loss 0.0640
# Epoch 44 Batch 300 Loss 0.0369
# Epoch 44 Batch 400 Loss 0.0324
# Epoch 44 Batch 500 Loss 0.0595
# Epoch 44 Batch 600 Loss 0.0234
# Epoch 44 Batch 700 Loss 0.0438
# Epoch 44 Batch 800 Loss 0.0526
# Epoch 44 Batch 900 Loss 0.0386
# Epoch 44 Batch 1000 Loss 0.0450
# Epoch 44 Batch 1100 Loss 0.0603
# Epoch 44 Batch 1200 Loss 0.0280
# Epoch 44 Loss 0.0466
# Time taken for 1 epoch 1906.9240176677704 sec
#
# Epoch 45 Batch 0 Loss 0.0482
# Epoch 45 Batch 100 Loss 0.0309
# Epoch 45 Batch 200 Loss 0.0285
# Epoch 45 Batch 300 Loss 0.0544
# Epoch 45 Batch 400 Loss 0.0534
# Epoch 45 Batch 500 Loss 0.0774
# Epoch 45 Batch 600 Loss 0.0712
# Epoch 45 Batch 700 Loss 0.0659
# Epoch 45 Batch 800 Loss 0.0703
# Epoch 45 Batch 900 Loss 0.0322
# Epoch 45 Batch 1000 Loss 0.0328
# Epoch 45 Batch 1100 Loss 0.0637
# Epoch 45 Batch 1200 Loss 0.0546
# Epoch 45 Loss 0.0464
# Time taken for 1 epoch 1934.872564315796 sec
#
# Epoch 46 Batch 0 Loss 0.0530
# Epoch 46 Batch 100 Loss 0.0278
# Epoch 46 Batch 200 Loss 0.0460
# Epoch 46 Batch 300 Loss 0.0530
# Epoch 46 Batch 400 Loss 0.0389
# Epoch 46 Batch 500 Loss 0.0212
# Epoch 46 Batch 600 Loss 0.0277
# Epoch 46 Batch 700 Loss 0.0281
# Epoch 46 Batch 800 Loss 0.0199
# Epoch 46 Batch 900 Loss 0.0460
# Epoch 46 Batch 1000 Loss 0.0773
# Epoch 46 Batch 1100 Loss 0.0395
# Epoch 46 Batch 1200 Loss 0.0408
# Epoch 46 Loss 0.0455
# Time taken for 1 epoch 1949.0394196510315 sec
#
# Epoch 47 Batch 0 Loss 0.0348
# Epoch 47 Batch 100 Loss 0.0448
# Epoch 47 Batch 200 Loss 0.0519
# Epoch 47 Batch 300 Loss 0.0316
# Epoch 47 Batch 400 Loss 0.0292
# Epoch 47 Batch 500 Loss 0.0470
# Epoch 47 Batch 600 Loss 0.0393
# Epoch 47 Batch 700 Loss 0.0770
# Epoch 47 Batch 800 Loss 0.0576
# Epoch 47 Batch 900 Loss 0.0437
# Epoch 47 Batch 1000 Loss 0.0731
# Epoch 47 Batch 1100 Loss 0.0299
# Epoch 47 Batch 1200 Loss 0.0602
# Epoch 47 Loss 0.0450
# Time taken for 1 epoch 1949.333867073059 sec
#
# Epoch 48 Batch 0 Loss 0.0388
# Epoch 48 Batch 100 Loss 0.0374
# Epoch 48 Batch 200 Loss 0.0604
# Epoch 48 Batch 300 Loss 0.0588
# Epoch 48 Batch 400 Loss 0.0389
# Epoch 48 Batch 500 Loss 0.0334
# Epoch 48 Batch 600 Loss 0.0360
# Epoch 48 Batch 700 Loss 0.0532
# Epoch 48 Batch 800 Loss 0.0451
# Epoch 48 Batch 900 Loss 0.0352
# Epoch 48 Batch 1000 Loss 0.0384
# Epoch 48 Batch 1100 Loss 0.0771
# Epoch 48 Batch 1200 Loss 0.0652
# Epoch 48 Loss 0.0444
# Time taken for 1 epoch 1958.5244686603546 sec
#
# Epoch 49 Batch 0 Loss 0.0468
# Epoch 49 Batch 100 Loss 0.0451
# Epoch 49 Batch 200 Loss 0.0252
# Epoch 49 Batch 300 Loss 0.0551
# Epoch 49 Batch 400 Loss 0.0356
# Epoch 49 Batch 500 Loss 0.0501
# Epoch 49 Batch 600 Loss 0.0437
# Epoch 49 Batch 700 Loss 0.0283
# Epoch 49 Batch 800 Loss 0.0647
# Epoch 49 Batch 900 Loss 0.0257
# Epoch 49 Batch 1000 Loss 0.0584
# Epoch 49 Batch 1100 Loss 0.0343
# Epoch 49 Batch 1200 Loss 0.0759
# Epoch 49 Loss 0.0449
# Time taken for 1 epoch 1947.9616210460663 sec
#
# Epoch 50 Batch 0 Loss 0.0086
# Epoch 50 Batch 100 Loss 0.0574
# Epoch 50 Batch 200 Loss 0.0391
# Epoch 50 Batch 300 Loss 0.0320
# Epoch 50 Batch 400 Loss 0.0387
# Epoch 50 Batch 500 Loss 0.0561
# Epoch 50 Batch 600 Loss 0.0531
# Epoch 50 Batch 700 Loss 0.0296
# Epoch 50 Batch 800 Loss 0.0764
# Epoch 50 Batch 900 Loss 0.0439
# Epoch 50 Batch 1000 Loss 0.0543
# Epoch 50 Batch 1100 Loss 0.0742
# Epoch 50 Batch 1200 Loss 0.0496
# Epoch 50 Loss 0.0438
# Time taken for 1 epoch 1959.0055997371674 sec

# %%
# функция для оценки перевода
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)
    # переводим каждый токен в индекс
    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')

    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    
    enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden)

        # storing the attention weights to plot later on
        predicted_id = tf.argmax(predictions[0]).numpy()
        # т.к. у нас нет таргета - передаём предсказание на следующий шаг
        result += targ_lang.index_word[predicted_id] + ' '
        # останавливаемся если встречаем токен конца
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def translate(sentence):
    result, sentence = evaluate(sentence)

    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's is here here . . . . . . .

# %% [markdown]
# Моделька тренируется долго, переводит так себе
